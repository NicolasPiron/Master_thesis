# %%
import functions.ERP as ERP

# %%
input_dir = '/Users/nicolaspiron/Documents/PULSATION/Python_MNE/output_preproc'
output_dir = '/Users/nicolaspiron/Documents/PULSATION/Python_MNE/output_preproc'
subject_id = '21'

# %%
ERP.plot_n2pc(subject_id=subject_id, input_dir=input_dir, output_dir=output_dir)
# Out:
# Reading /Users/nicolaspiron/Documents/PULSATION/Python_MNE/output_preproc/sub-21/cleaned_epochs/sub-21-cleaned_epochs-N2pc.fif ...
#     Found the data of interest:
#         t =    -199.22 ...     798.83 ms
#         0 CTF compensation matrices available
# /Users/nicolaspiron/Documents/Master_thesis/EEG/functions/ERP.py:36: RuntimeWarning: This filename (/Users/nicolaspiron/Documents/PULSATION/Python_MNE/output_preproc/sub-21/cleaned_epochs/sub-21-cleaned_epochs-N2pc.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(os.path.join(input_dir, f'sub-{subject_id}', 'cleaned_epochs', f'sub-{subject_id}-cleaned_epochs-N2pc.fif'))
# Not setting metadata
# 464 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/nicolaspiron/Documents/Master_thesis/EEG/functions/ERP.py:39: RuntimeWarning: tmin is not in time interval. tmin is set to <class 'mne.epochs.EpochsFIF'>.tmin (-0.199219 sec)
#   epochs.crop(tmin=tmin, tmax=tmax)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)

# %%
ERP.get_n2pc_values(subject_id, input_dir, output_dir)
# Out:
# Reading /Users/nicolaspiron/Documents/PULSATION/Python_MNE/output_preproc/sub-21/cleaned_epochs/sub-21-cleaned_epochs-N2pc.fif ...
#     Found the data of interest:
#         t =    -199.22 ...     798.83 ms
#         0 CTF compensation matrices available
# /Users/nicolaspiron/Documents/Master_thesis/EEG/functions/ERP.py:36: RuntimeWarning: This filename (/Users/nicolaspiron/Documents/PULSATION/Python_MNE/output_preproc/sub-21/cleaned_epochs/sub-21-cleaned_epochs-N2pc.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(os.path.join(input_dir, f'sub-{subject_id}', 'cleaned_epochs', f'sub-{subject_id}-cleaned_epochs-N2pc.fif'))
# Not setting metadata
# 464 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/nicolaspiron/Documents/Master_thesis/EEG/functions/ERP.py:39: RuntimeWarning: tmin is not in time interval. tmin is set to <class 'mne.epochs.EpochsFIF'>.tmin (-0.199219 sec)
#   epochs.crop(tmin=tmin, tmax=tmax)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
#    ID   condition and side  ealry 200-300ms  late 300-400ms  total 200-400ms
# 0  21     Dis_mid (Contra)     -6.67501e-06     2.11257e-06     -2.28122e-06
# 1  21       Dis_mid (Ipsi)     -6.51071e-06     2.30034e-06     -2.10518e-06
# 2  21      No_dis (Contra)     -6.55300e-06     1.07196e-06     -2.74052e-06
# 3  21        No_dis (Ipsi)     -6.17747e-06     1.90447e-06     -2.13650e-06
# 4  21  Dis_contra (Contra)     -6.59731e-06     1.72222e-06     -2.43755e-06
# 5  21    Dis_contra (Ipsi)     -6.46551e-06     2.35061e-06     -2.05745e-06
