# %%
import mne
import functions.ERP as ERP

# %%
input_dir = '/Users/nicolaspiron/Documents/PULSATION/Python_MNE/output_preproc'
output_dir = '/Users/nicolaspiron/Documents/PULSATION/Python_MNE'
subject_id = '21'

# %%
ERP.plot_n2pc(subject_id=subject_id, input_dir=input_dir, output_dir=output_dir)
# Out:
# Reading /Users/nicolaspiron/Documents/PULSATION/Python_MNE/output_preproc/sub-21/cleaned_epochs/sub-21-cleaned_epochs-N2pc.fif ...
#     Found the data of interest:
#         t =    -199.22 ...     798.83 ms
#         0 CTF compensation matrices available
# /Users/nicolaspiron/Documents/Master_thesis/EEG/functions/ERP.py:25: RuntimeWarning: This filename (/Users/nicolaspiron/Documents/PULSATION/Python_MNE/output_preproc/sub-21/cleaned_epochs/sub-21-cleaned_epochs-N2pc.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(os.path.join(input_dir, f'sub-{subject_id}', 'cleaned_epochs', f'sub-{subject_id}-cleaned_epochs-N2pc.fif'))
# Not setting metadata
# 455 matching events found
# No baseline correction applied
# 0 projection items activated
# /Users/nicolaspiron/Documents/Master_thesis/EEG/functions/ERP.py:28: RuntimeWarning: tmin is not in time interval. tmin is set to <class 'mne.epochs.EpochsFIF'>.tmin (-0.199219 sec)
#   epochs.crop(tmin=tmin, tmax=tmax)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
